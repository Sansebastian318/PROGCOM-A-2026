# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidMutis777/PROGCOM-A-2026/blob/main/Clase_0_Aprendiendo_Colab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bienvenida

# %% [markdown]
# ##Aprendiendo a usar print
# Print() es un método que permite imprimir información en consola
#
#
#
# ```
# if (condicion)==verdadera
#   print("Pasan cositas")
# else:
#   print("pasan cositas")
# ```
# El print() puede imprimir lo siguiente:
#    1. Cualquier tipo de dato
#    2. Cualquier método o función (su dirección en memoria)
#    3. Concatenacióm de texto
#    4. Operaciones matemáticas

# %% [markdown]
# ##Conociendo el input
# Input() es un método con triple función
# * Declara: toda la información que ingresa con este método, se declara automáticamente como string (caracter).
# * Lee: Porque alamacena una variable
# * Imprime: Porque lo que está entre los paréntesis, se visualiza en consola

# %%
a=24
b=50
a+b
# Out:
# 74

# %% [markdown]
# ###CONCATENACIÓN
# Concatenar es unir dos tipos diferentes de datos

# %%
x=int(input("ingrese su edad: "))
y=input("ingrese su nombre: ")
# Out:
# ingrese su edad: 20
# ingrese su nombre: jajaj

# %%
#Ejemplo 1
print(y,"tiene una edad de ",x)
# Out:
# jajaj tiene una edad de  20

# %%
#Ejemplo 2
print(y+" tiene una edad de "+str(x))
# Out:
# jajaj tiene una edad de 20

# %%
#Ejemplo 3
print(f"{y} tiene una edad de {x}")
# Out:
# jajaj tiene una edad de 20
