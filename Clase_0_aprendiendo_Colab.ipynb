# %% [markdown]
# <a href="https://colab.research.google.com/github/Sansebastian318/PROGCOM-A-2026/blob/main/Clase_0_aprendiendo_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Aprendiendo a usar print
# print() es un metodo que ayuda a imprimir en información consola
#
#
# ```
# if (condition)==verdadera
#   print("pasan cositas")
# else:
#    print("pasan cositas")
# ```
# El print() puede imprimir lo siguiente:
# 1. Cualquier tipo de dato
# 2. Cualquier metodo o función(su dirección de memoria)
# 3. Concatenacion de texto
# 4. Operaciones matematicas

# %% [markdown]
# ##Conociendo el input
# input() es un metodo con triple funcion
# *declara: toda la informacion que ingresa con este metodo, se declara automaticamente como string (caracter).
# *Lee: porque almacena en una variable.
# *imprime:porque lo que esta entre los parentesis, se visualiza en la consola

# %%
a=24
b=50
a+b
# Out:
# 74

# %% [markdown]
# ###Concatenacion
# Concatenar es unir dos tipos diferentes de datos

# %%
x=int(input("ingrese su edad: "))
y=input("ingrese su nombre: ")
# Out:
# ingrese su edad: 20
# ingrese su nombre: Sebastian

# %%
#ejemplo 1
print(y,"Tiene edad de ",x)
# Out:
# Sebastian Tiene edad de  20

# %%
#ejemplo 2
print(y+ " tiene una edad de "+str(x))
# Out:
# Sebastian tiene una edad de 20

# %%
#ejemplo 3
print(f"{y} tiene una edad de {x}")
# Out:
# Sebastian tiene una edad de 20
